# %%
# import necessary libraries
import pandas as pd
import os
import glob
  
path = os.getcwd() # This command will get you right into the folder where notebooks is being created.
csv_files = glob.glob(os.path.join(path, "*.csv")) # This is to take all the files.

mdf = [] #Creating an empty list

# To take all the files one by one into one place.
for f in csv_files:
    df = pd.read_csv(f) # read the csv file. f means taking file one by one.
    mdf.append(df) # Appending the file into one place but keeping a separator between the files.
    print('Location:', f) #This is just to see, where the files is being taken from.
    print('File Name:', f.split("\\")[-1]) #Again this is just to see file name.
        
df_master = pd.concat(mdf, axis=0, ignore_index=True) #Finally removing the separator and dumping all the data into one file.
# Out:
# Location: C:\Users\ZORD PC\Documents\Documents\Studies\Online Studies\Studies\Self Study\New Learning\temp\1.csv
# File Name: 1.csv
# Location: C:\Users\ZORD PC\Documents\Documents\Studies\Online Studies\Studies\Self Study\New Learning\temp\2.csv
# File Name: 2.csv
# Location: C:\Users\ZORD PC\Documents\Documents\Studies\Online Studies\Studies\Self Study\New Learning\temp\3.csv
# File Name: 3.csv
# Location: C:\Users\ZORD PC\Documents\Documents\Studies\Online Studies\Studies\Self Study\New Learning\temp\4.csv
# File Name: 4.csv

# %%
df_master
# Out:
#       instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0           1    1/1/2011       1   0     1        0        6           0
# 1           2    1/2/2011       1   0     1        0        0           0
# 2           3    1/3/2011       1   0     1        0        1           1
# 3           4    1/4/2011       1   0     1        0        2           1
# 4           5    1/5/2011       1   0     1        0        3           1
# ...       ...         ...     ...  ..   ...      ...      ...         ...
# 2919      727  12/27/2012       1   1    12        0        4           1
# 2920      728  12/28/2012       1   1    12        0        5           1
# 2921      729  12/29/2012       1   1    12        0        6           0
# 2922      730  12/30/2012       1   1    12        0        0           0
# 2923      731  12/31/2012       1   1    12        0        1           1
#
#       weathersit      temp     atemp       hum  windspeed  rentals
# ...
